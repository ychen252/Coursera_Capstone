# %% [markdown]
# ## Yihan Chen's Capstone Project - IBM Data Science Professional Certificate ##

# %% [markdown]
# This Notebook is mainly used for Yihan Chen's Capstone Project Submission

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
